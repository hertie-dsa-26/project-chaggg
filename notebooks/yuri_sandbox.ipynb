# %% [markdown]
# Loading the libraries

# %%
import sys
import os
import pandas as pd

# Now import
from scripts.utils import load_data  # Not "from scripts.utils"

# Load data
df = load_data()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 6
#       3 import pandas as pd
#       5 # Now import
# ----> 6 from scripts.utils import load_data  # Not "from scripts.utils"
#       8 # Load data
#       9 df = load_data()
#
# ModuleNotFoundError: No module named 'scripts'

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7898407 entries, 0 to 7898406
# Data columns (total 36 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   id                    int64
#  1   case_number           str
#  2   date                  str
#  3   block                 str
#  4   iucr                  str
#  5   primary_type          str
#  6   description           str
#  7   location_description  str
#  8   arrest                bool
#  9   domestic              bool
#  10  beat                  int64
#  11  district              float64
#  12  ward                  float64
#  13  community_area        float64
#  14  fbi_code              str
#  15  year                  int64
#  16  updated_on            str
#  17  x_coordinate          float64
#  18  y_coordinate          float64
#  19  latitude              float64
#  20  longitude             float64
#  21  time                  str
#  22  month                 int64
# ...

# %%
df['description'].unique()
# Out:
# <ArrowStringArray>
# [                                              '$500 AND UNDER',
#                                                   'TO PROPERTY',
#                                                    'AUTOMOBILE',
#                                       'AGG: FINANCIAL ID THEFT',
#                                                     'OVER $500',
#                                 'FINANCIAL ID THEFT: OVER $300',
#                                                    'TO VEHICLE',
#                                      'FRAUD OR CONFIDENCE GAME',
#                                       'HARASSMENT BY TELEPHONE',
#                                             'CREDIT CARD FRAUD',
#  ...
#                        'INTERNET OFFENSES - ELECTRONIC FENCING',
#         'DISTRIBUTION PHOTOGRAPH DEPICTING SEX ORGANS OF CHILD',
#  'PUBLIC AIR WIRE AND MAIL FRAUD - VIA WIRE, RADIO, TELEVISION',
#    'UNAUTH VIDEO RECORD/TRANSMIT LIVE VIDEO UNDER/THRU CLOTHES',
# ...

# %% [markdown]
# changing CRIM Sexual Assault to be CRIMINAL SEXUAL ASSAULT

# %%
# Fix the typo
df['primary_type'] = df['primary_type'].replace('CRIM SEXUAL ASSAULT', 'CRIMINAL SEXUAL ASSAULT')

# Save back
df.to_parquet('/Users/yuriirrgang/Library/Mobile Documents/com~apple~CloudDocs/Hertie/project-chaggg/data/cleaned/chicago_crimes_cleaned.parquet', index=False)

print("Done. Unique primary_types now:")
print(sorted(df['primary_type'].unique()))
print(df['primary_type'].value_counts())
# Out:
# Done. Unique primary_types now:
# ['ARSON', 'ASSAULT', 'BATTERY', 'BURGLARY', 'CONCEALED CARRY LICENSE VIOLATION', 'CRIMINAL DAMAGE', 'CRIMINAL SEXUAL ASSAULT', 'CRIMINAL TRESPASS', 'DECEPTIVE PRACTICE', 'GAMBLING', 'HOMICIDE', 'HUMAN TRAFFICKING', 'INTERFERENCE WITH PUBLIC OFFICER', 'INTIMIDATION', 'KIDNAPPING', 'LIQUOR LAW VIOLATION', 'MOTOR VEHICLE THEFT', 'NARCOTICS', 'NON-CRIMINAL', 'OBSCENITY', 'OFFENSE INVOLVING CHILDREN', 'OTHER NARCOTIC VIOLATION', 'OTHER OFFENSE', 'PROSTITUTION', 'PUBLIC INDECENCY', 'PUBLIC PEACE VIOLATION', 'RITUALISM', 'ROBBERY', 'SEX OFFENSE', 'STALKING', 'THEFT', 'WEAPONS VIOLATION']
# primary_type
# THEFT                                1680404
# BATTERY                              1444207
# CRIMINAL DAMAGE                       903471
# NARCOTICS                             701922
# ASSAULT                               535128
# OTHER OFFENSE                         494637
# BURGLARY                              420079
# ...

# %%
df.head()
df.info()
